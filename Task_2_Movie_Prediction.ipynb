# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanza36/CodSoft/blob/main/Task_2_Movie_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *  Shanza Naveed
# *  Batch: January
#
#
# *  Internship: Winter
#
# *  Company: CodSoft
# *  Field: Data Science
#
#
# *  Task_2: Movie rating

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sklearn

# %%
# !pip install chardet

# %%
import chardet

# %%
with open('/content/drive/MyDrive/moovy.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

# %%
df_movie = pd.read_csv('/content/drive/MyDrive/moovy.csv', encoding=encoding)
df_movie.dropna(inplace=True)
df_movie.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_movie.shape
# Out:
# (5659, 10)

# %%
df_movie.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_movie.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
with open('/content/drive/MyDrive/Ratings.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

# %%
df_ratings = pd.read_csv('/content/drive/MyDrive/Ratings.csv', encoding=encoding)
df_ratings.dropna(inplace=True)
df_ratings.head()
# Out:
#    Rating
# 0     7.0
# 1     4.4
# 2     4.7
# 3     7.4
# 4     5.6

# %%
df_ratings.shape
# Out:
# (7919, 1)

# %%
df_ratings.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
df_ratings.isna().sum()
# Out:
# Rating    0
# dtype: int64

# %%
sns.countplot(x=df_movie['Genre'], hue=df_movie['Rating'])
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.countplot(x=df_movie['Name'], hue=df_movie['Rating'])
# Out:
# <Axes: xlabel='Name', ylabel='count'>

# %%
X=df_movie['Votes']
Y=df_movie['Rating']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 42 )

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(random_state = 42)
log.fit(X_train, Y_train)

# %%
pred = print(log.predict(X_test))

# %%
print(Y_test)
